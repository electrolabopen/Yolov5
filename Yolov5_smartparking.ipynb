# %% [markdown]
# <a href="https://colab.research.google.com/github/electrolabopen/Yolov5/blob/main/Yolov5_smartparking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/anil2k/smart-car-parking-yolov5
# Out:
# Cloning into 'smart-car-parking-yolov5'...
# remote: Enumerating objects: 184, done.
# remote: Counting objects: 100% (184/184), done.
# remote: Compressing objects: 100% (160/160), done.
# remote: Total 184 (delta 84), reused 87 (delta 21), pack-reused 0
# Receiving objects: 100% (184/184), 5.06 MiB | 15.50 MiB/s, done.
# Resolving deltas: 100% (84/84), done.

# %%
# %cd /content/smart-car-parking-yolov5
# Out:
# /content/smart-car-parking-yolov5

# %%
# %cd /content/smart-car-parking-yolov5/yolov5
# Out:
# /content/smart-car-parking-yolov5/yolov5

# %%
# !pip install -U -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 10.3MB 7.6MB/s
# ...
#      |████████████████████████████████| 15.3MB 171kB/s
# ...
#      |████████████████████████████████| 51.0MB 57kB/s
# ...
#      |████████████████████████████████| 3.0MB 48.9MB/s
# Requirement already up-to-date: PyYAML>=5.3.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 8)) (5.4.1)
# ...
#      |████████████████████████████████| 27.4MB 120kB/s
# Requirement already up-to-date: torch>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 10)) (1.8.1+cu101)
# Requirement already up-to-date: torchvision>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 11)) (0.9.1+cu101)
# ...
#      |████████████████████████████████| 81kB 13.6MB/s
# Requirement already up-to-date: tensorboard>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 15)) (2.5.0)
# ...

# %%
from IPython.display import Image, clear_output

# %%
# %cd /content/smart-car-parking-yolov5/yolov5
# Out:
# /content/smart-car-parking-yolov5/yolov5

# %%
# !python detect_customize.py --weights yolov5m.pt  --img 640 --conf 0.70 --source po.mp4 --save-txt --class 2
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=[2], conf_thres=0.7, device='', exist_ok=False, hide_conf=False, hide_labels=False, img_size=640, iou_thres=0.45, line_thickness=1, name='exp', nosave=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=True, source='po.mp4', update=False, view_img=False, weights=['yolov5m.pt'])
# YOLOv5 🚀 01c7634 torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...
# 100% 41.1M/41.1M [00:00<00:00, 46.8MB/s]
#
# Fusing layers...
# Model Summary: 308 layers, 21356877 parameters, 0 gradients
# video 1/1 (1/538) /content/smart-car-parking-yolov5/yolov5/po.mp4: 448x640 Done. (0.038s)
# video 1/1 (2/538) /content/smart-car-parking-yolov5/yolov5/po.mp4: 448x640 Done. (0.018s)
# video 1/1 (3/538) /content/smart-car-parking-yolov5/yolov5/po.mp4: 448x640 Done. (0.018s)
# video 1/1 (4/538) /content/smart-car-parking-yolov5/yolov5/po.mp4: 448x640 Done. (0.018s)
# ...
